# %% [markdown]
# # Step 7 — Pixel-based Baselines (ERFNet)
# Evaluates MSP, MaxLogit, MaxEntropy anomaly scoring on 5 datasets.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clone repo (branch corretto) and move into eval folder
import os

REPO_URL = "https://github.com/flaviofrasca/MaskArchitectureAnomaly_CourseProject.git"
REPO_DIR = "/content/MaskArchitectureAnomaly_CourseProject"
BRANCH   = "step_8"

if not os.path.exists(REPO_DIR):
    # !git clone -b {BRANCH} {REPO_URL} {REPO_DIR}
else:
    # !git -C {REPO_DIR} fetch origin
    # !git -C {REPO_DIR} checkout {BRANCH}
    # !git -C {REPO_DIR} pull origin {BRANCH}
    print("Repo aggiornato")

# %cd {REPO_DIR}/eval
# Out:
# Cloning into '/content/MaskArchitectureAnomaly_CourseProject'...
# remote: Enumerating objects: 348, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 348 (delta 75), reused 57 (delta 57), pack-reused 209 (from 3)
# Receiving objects: 100% (348/348), 28.51 MiB | 21.59 MiB/s, done.
# Resolving deltas: 100% (114/114), done.
# /content/MaskArchitectureAnomaly_CourseProject/eval

# %%
# Install missing dependency
# !pip install ood-metrics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 77.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.52.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.

# %%
# Verify dataset structure and ERFNet weights
import os

BASE = "/content/drive/.shortcut-targets-by-id/1osgiWms0a4SYz1evCZNwMV-jv--0I0RU/MaskArch_Shared"
ANOMALY_DIR = BASE + "/datasets/anomaly"

print("=== Dataset structure ===")
for root, dirs, files in os.walk(ANOMALY_DIR):
    level = root.replace(ANOMALY_DIR, '').count(os.sep)
    print('  ' * level + os.path.basename(root) + '/')
    for f in sorted(files)[:3]:
        print('  ' * (level + 1) + f)

print("\n=== ERFNet weights ===")
weights_path = "../trained_models/erfnet_pretrained.pth"
print("Found:", os.path.exists(weights_path), "→", weights_path)
# Out:
# === Dataset structure ===
# anomaly/
#   RoadAnomaly21/
#     .DS_Store
#     images/
#       0.png
#       1.png
#       2.png
#     labels_masks/
#       0.png
#       1.png
#       2.png
#   RoadAnomaly/
#     .DS_Store
#     images/
#       0.jpg
#       1.jpg
#       10.jpg
#     labels_masks/
#       0.png
#       1.png
#       10.png
#   RoadObsticle21/
#     .DS_Store
#     labels_masks/
#       0.png
#       1.png
#       10.png
#     images/
#       0.webp
#       1.webp
#       10.webp
#   fs_static/
#     .DS_Store
#     labels_masks/
#       0.png
#       1.png
#       10.png
#     images/
#       0.jpg
#       1.jpg
#       10.jpg
#   LostAndFound/
#     .DS_Store
#     labels_masks/
#       0.png
#       1.png
#       10.png
#     images/
#       0.png
#       1.png
#       10.png
#
# === ERFNet weights ===
# Found: True → ../trained_models/erfnet_pretrained.pth

# %%
# Run MSP
# !python evalAnomaly.py --method MSP
# Out:
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
#
# ============================================================
# Method: MSP
# ============================================================
# Dataset                 AuPRC    FPR95
# ----------------------------------------
# SMIYC RA-21            29.10%   62.55%
# SMIYC RO-21             2.71%   65.22%
# FS L&F                  1.75%   50.59%
# FS Static               7.47%   41.84%
# Road Anomaly           12.42%   82.58%
# ============================================================
#
# Results appended to results.txt

# %%
# Run MaxLogit
# !python evalAnomaly.py --method MaxLogit
# Out:
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
#
# ============================================================
# Method: MaxLogit
# ============================================================
# Dataset                 AuPRC    FPR95
# ----------------------------------------
# SMIYC RA-21            38.32%   59.34%
# SMIYC RO-21             4.63%   48.44%
# FS L&F                  3.30%   45.49%
# FS Static               9.50%   40.30%
# Road Anomaly           15.58%   73.25%
# ============================================================
#
# Results appended to results.txt

# %%
# Run MaxEntropy
# !python evalAnomaly.py --method MaxEntropy
# Out:
# Loading weights: ../trained_models/erfnet_pretrained.pth
# Model and weights LOADED successfully
#
# ============================================================
# Method: MaxEntropy
# ============================================================
# Dataset                 AuPRC    FPR95
# ----------------------------------------
# SMIYC RA-21            30.97%   62.66%
# SMIYC RO-21             3.04%   65.91%
# FS L&F                  2.58%   50.16%
# FS Static               8.84%   41.55%
# Road Anomaly           12.67%   82.75%
# ============================================================
#
# Results appended to results.txt

# %%
# Print all results
with open("results.txt") as f:
    print(f.read())
# Out:
#     AUPRC score:13.194873989049796   FPR@TPR95:97.01270448916142
#     AUPRC score:13.194873989049796   FPR@TPR95:97.01270448916142
# === ERFNet | Method: MSP ===
#   SMIYC RA-21          AuPRC: 29.10%  FPR@95: 62.55%
#   SMIYC RO-21          AuPRC: 2.71%  FPR@95: 65.22%
#   FS L&F               AuPRC: 1.75%  FPR@95: 50.59%
#   FS Static            AuPRC: 7.47%  FPR@95: 41.84%
#   Road Anomaly         AuPRC: 12.42%  FPR@95: 82.58%
#
# === ERFNet | Method: MaxLogit ===
#   SMIYC RA-21          AuPRC: 38.32%  FPR@95: 59.34%
#   SMIYC RO-21          AuPRC: 4.63%  FPR@95: 48.44%
#   FS L&F               AuPRC: 3.30%  FPR@95: 45.49%
#   FS Static            AuPRC: 9.50%  FPR@95: 40.30%
#   Road Anomaly         AuPRC: 15.58%  FPR@95: 73.25%
#
# === ERFNet | Method: MaxEntropy ===
#   SMIYC RA-21          AuPRC: 30.97%  FPR@95: 62.66%
#   SMIYC RO-21          AuPRC: 3.04%  FPR@95: 65.91%
#   FS L&F               AuPRC: 2.58%  FPR@95: 50.16%
#   FS Static            AuPRC: 8.84%  FPR@95: 41.55%
#   Road Anomaly         AuPRC: 12.67%  FPR@95: 82.75%
